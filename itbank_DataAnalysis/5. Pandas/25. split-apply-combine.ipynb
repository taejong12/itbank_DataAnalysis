# %% [markdown]
# # Split - Apply - Combine strategy
#
# ![](https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9978503F5B8264490F)

# %% [markdown]
# ![](https://t1.daumcdn.net/cfile/tistory/9961104E5B8BB34A22)

# %% [markdown]
# ###### 데이터 둘러보기

# %% [markdown]
# ## aggregate(집계) 함수 사용하기
#  - groupby 결과에 '집계함수'를 적용하여 그룹별 데이터 확인 가능
#  - ex) sum(), count(), mean(), max() ...

# %% [markdown]
# ### 대륙별 grouping
# split!

# %% [markdown]
# ##### groupby 객체도 iterable 하다!

# %% [markdown]
# ## 대륙 x 지역별 그룹핑

# %% [markdown]
# ### GroupBy 에 적용 가능한 집계함수(aggregate func)들
# sum(), count(), mean() 등 적용 가능
#
# - 이 과정 또한 split-apply-combine

# %% [markdown]
# ## 대륙별 인구수 합계 (방법1)

# %% [markdown]
# ## 대륙별 인구수 합계 (방법2)
# - agg() + 집계함수 사용

# %% [markdown]
# #### ★ groupby(...)   의 매개변수로  문자열, 함수, 리스트, Series, level= 등 여러가지 형태가 들어갈수 있다

# %% [markdown]
# ## 각 알파벳으로 시작하는 국가들은 각각 몇개나 될까?

# %% [markdown]
# ###### groupby(  꼭 원본과 같은 크기의 데이터 일 필요는 없다 !)

# %% [markdown]
# ## 대륙별 인구가 가장 많은 국가 1개씩

# %% [markdown]
# # 대륙별, 인구합계,인구평균, 면적합계
# - 대륙별
#     - 인구는 "합계","평균"
#     - 면적은 "합계 "

# %% [markdown]
# [예시]
# ![image.png](attachment:image.png)
