# %% [markdown]
# # Split - Apply - Combine

# %% [markdown]
# # 타이타닉호 성별 x 객실별 승객수 구하기
# 'Sex' x 'Pclass'

# %% [markdown]
# [예시]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 타이타닉호 성별 x 객실별 생존률 구하기
# 'Sex' x 'Pclass'

# %% [markdown]
# [예시]
# ![image.png](attachment:image.png)
