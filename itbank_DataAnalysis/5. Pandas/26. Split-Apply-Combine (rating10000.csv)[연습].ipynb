# %%
import numpy as np
import pandas as pd

# %%
filepath = r'data\ratings.csv'

df = pd.read_csv(filepath)
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# # 유저별 영화 '평점수','평점 평균'을 구하기
# - 평점수 많은순 (내림차순)으로 정렬하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 영화평이 10개 이상인 영화 중에서, 평점평균 이 가장 높은 영화의 Top 10 뽑기
# - 평점평균 내림차순으로 정렬
# - columns 이름은 '평점개수', '평점평균'
# - index 는 영화id

# %% [markdown]
# ![image.png](attachment:image.png)
